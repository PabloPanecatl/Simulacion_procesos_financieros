# %% [markdown]
# # Random walk
# Primero hacemos las simulaciones de caminatas aleatorias

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(42)

n_steps =200
steps = np.random.choice([-1,1], size=n_steps)
price =100 + np.cumsum(steps)

plt.figure(figsize=(10,5))
plt.plot(price)
plt.title("Random Walk de un precio")
plt.xlabel("Tiempo")
plt.ylabel("Precio")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(1)

n_sim =5000
n_steps =200

final_positions = []

for _ in range(n_sim):
    steps = np.random.choice([-1,1], size=n_steps)
    final_positions.append(np.sum(steps))

plt.hist(final_positions, bins=50)
plt.title("Distribución de posiciones finales")
plt.show()

# %%
import numpy as np

np.random.seed(0)

n_sim =2000
times = [10,50,100,200,400]

for t in times:
    finals = []
    for _ in range(n_sim):
        steps = np.random.choice([-1,1], size=t)
        finals.append(np.sum(steps))
print(f"t={t}, var≈{np.var(finals):.2f}")
# Out:
# t=400, var≈407.04

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(42)

T = 1
n = 1000
dt = T/n

increments = np.random.normal(0, np.sqrt(dt), size=n)
W = np.cumsum(increments)

plt.plot(W)
plt.title("Aproximación a movimiento browniano")
plt.show()

# %% [markdown]
# ## Actividad de clase
# Sacar el promedio del precio para cada caminata aleatoria

# %%
#Grafica 200 caminatas aleatorias juntas
#Grafica el promedio de las 200 en cada momento t
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(42)
n_steps =200
n_walks =200
all_prices = []
for _ in range(n_walks):
    steps = np.random.choice([-1,1], size=n_steps)
    price =100 + np.cumsum(steps)
    all_prices.append(price)
    plt.plot(price, color='lightgray', alpha=0.5)
average_price = np.mean(all_prices, axis=0)
plt.plot(average_price, color='blue', label='Promedio de Caminatas', linewidth=2)
plt.title("200 Caminatas Aleatorias y su Promedio")
plt.xlabel("Tiempo")
plt.ylabel("Precio")
plt.legend()
plt.show()
